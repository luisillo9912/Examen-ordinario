# %%
#Importamos las librerias que vamos a utilizar
#Panda es una libreria de python que nos permite hacer data frames
import pandas as pd
#Numpy es para operaciones de matrices
import numpy as np
#Seaborn es para graficar y hacer comparativos
import seaborn as sns

#Graficas de forma general
#import matplotlib as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
ls
# Out:
# 57654-0.txt                   postgresql-practice-master (1).zip
# archive.zip                   Práctica clases 18 de enero - Netflix.ipynb
# city_temperature.csv          simple.json
# data_by_artist.csv            spotify_dataset.zip
# data_by_genres.csv            Temperaturas.ipynb
# data_by_year.csv              Untitled10.ipynb
# data.csv                      Untitled1.ipynb
# Data from html.ipynb          Untitled2.ipynb
# Data from HTML.ipynb          Untitled3.ipynb
# data_w_genres.csv             Untitled4.ipynb
# ETL completo .ipynb           Untitled5.ipynb
# Examen del 2 parcial.ipynb    Untitled6.ipynb
# Examen segundo parcial.ipynb  Untitled7.ipynb
# Explorando datos.ipynb        Untitled8.ipynb
# Libros.ipynb                  Untitled9.ipynb
# lost+found/                   Untitled.ipynb
# Pandas.ipynb                  vino_data.zip
# Pokemon.csv                   vinos_datas.zip

# %%
#Extraemos los datos de la librería
# !unzip vino_data.zip
# Out:
# Archive:  vino_data.zip
#   inflating: winemag-data-130k-v2.csv
#   inflating: winemag-data-130k-v2.json
#   inflating: winemag-data_first150k.csv

# %%
ls
# Out:
# 57654-0.txt                                  simple.json
# archive.zip                                  spotify_dataset.zip
# city_temperature.csv                         Temperaturas.ipynb
# data_by_artist.csv                           Untitled10.ipynb
# data_by_genres.csv                           Untitled11.ipynb
# data_by_year.csv                             Untitled1.ipynb
# data.csv                                     Untitled2.ipynb
# Data from html.ipynb                         Untitled3.ipynb
# Data from HTML.ipynb                         Untitled4.ipynb
# data_w_genres.csv                            Untitled5.ipynb
# ETL completo .ipynb                          Untitled6.ipynb
# Examen del 2 parcial.ipynb                   Untitled7.ipynb
# Examen segundo parcial.ipynb                 Untitled8.ipynb
# Explorando datos.ipynb                       Untitled9.ipynb
# Libros.ipynb                                 Untitled.ipynb
# ...

# %%
#Creamos las variables para poder hacer dataframes con lo extraido anteriormente
df = pd.read_csv("winemag-data_first150k.csv", encoding='latin')

# %%
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La BÃ©gude, named af...
#
#                              designation  points  price        province  \
# 0                      Martha's Vineyard      96  235.0      California
# 1  Carodorum SelecciÃ³n Especial Reserva      96  110.0  Northern Spain
# 2          Special Selected Late Harvest      96   90.0      California
# 3                                Reserve      96   65.0          Oregon
# 4                            La BrÃ»lade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
#1 ¿Cuáles son las 5 variedades de vino más abundantes y menos abundantes?
#Abundantes
sp = df.head(5).sort_values(by='variety', ascending=True)

# %%
sp
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La BÃ©gude, named af...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
#
#                              designation  points  price        province  \
# 0                      Martha's Vineyard      96  235.0      California
# 3                                Reserve      96   65.0          Oregon
# 4                            La BrÃ»lade      95   66.0        Provence
# 2          Special Selected Late Harvest      96   90.0      California
# 1  Carodorum SelecciÃ³n Especial Reserva      96  110.0  Northern Spain
#
#             region_1           region_2             variety  \
# ...

# %%
#MENOS ABUNDANTES
sd = df.head(150929).sort_values(by='variety', ascending=False)

# %%
sd
# Out:
#         Unnamed: 0    country  \
# 5215          5215  Macedonia
# 5050          5050  Macedonia
# 80433        80433    Austria
# 85597        85597    Austria
# 111264      111264    Austria
# ...            ...        ...
# 56230        56230     Greece
# 119287      119287     Greece
# 35480        35480     Greece
# 113780      113780     Greece
# 107905      107905     Greece
#
#                                               description  \
# 5215    This Macedonian white is bright yellow with gr...
# 5050    This Macedonian wine made from 100% Å½ilavka h...
# 80433   Yes, cherry is a good name for the red cherry ...
# 85597   This has rich fruits that are solid and firmly...
# 111264  This is in the fresh, fruity style of Zweigelt...
# ...                                                   ...
# 56230   Sweet, jammy aromas and flavors of red berry, ...
# 119287  This plucky red starts with aromas of tobacco,...
# 35480   Cigarbox, mint, balsamic and leather lead this...
# ...

# %%
dr = pd.read_csv("winemag-data-130k-v2.csv", encoding='latin')

# %%
dr.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# ...

# %%
#De acuerdo a su nacionalidad ¿Cuál es el vino más lejano a Mérida
sd = df.head().sort_values(by='country', ascending=True)

# %%
sd
# Out:
#    Unnamed: 0 country                                        description  \
# 4           4  France  This is the top wine from La BÃ©gude, named af...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
#
#                              designation  points  price        province  \
# 4                            La BrÃ»lade      95   66.0        Provence
# 1  Carodorum SelecciÃ³n Especial Reserva      96  110.0  Northern Spain
# 0                      Martha's Vineyard      96  235.0      California
# 2          Special Selected Late Harvest      96   90.0      California
# 3                                Reserve      96   65.0          Oregon
#
#             region_1           region_2             variety  \
# ...

# %%
#Indique si existe alguna relación lineal entre los puntos del vino y su precio
relation = df[['price','points']]

# %%
relation
# Out:
#         price  points
# 0       235.0      96
# 1       110.0      96
# 2        90.0      96
# 3        65.0      96
# 4        66.0      95
# ...       ...     ...
# 150925   20.0      91
# 150926   27.0      91
# 150927   20.0      91
# 150928   52.0      90
# 150929   15.0      90
#
# [150930 rows x 2 columns]

# %%
#4 ¿Cuál es el valor promedio del precio de los vinos?
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  150930.000000  150930.000000  137235.000000
# mean    75464.500000      87.888418      33.131482
# std     43569.882402       3.222392      36.322536
# min         0.000000      80.000000       4.000000
# 25%     37732.250000      86.000000      16.000000
# 50%     75464.500000      88.000000      24.000000
# 75%    113196.750000      90.000000      40.000000
# max    150929.000000     100.000000    2300.000000

# %%
#El catador voss roger tiene el 20% de los vinos ¿Cuántos vinos son?
dr.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin OâKeefe       10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne KrebiehlÂ MW      3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
dr.taster_name.value_counts(Roger Voss *.20)
# Out:
#   File "<ipython-input-67-f4daeef2a419>", line 1
#     dr.taster_name.value_counts(Roger Voss *.20)
#                                          ^
# SyntaxError: invalid syntax
